# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

import numpy as np
import pandas as pd

from pathlib import Path
import os

from sklearn import metrics

import sys

# %%
data_path = Path(os.path.abspath('')) / "processed" / "pcs.csv"

# %%
data = pd.read_csv(data_path, sep=',')

# %%
data
# Out:
#                                              prog_name  hours_total  \
# 0    способ и средство защита информация от несанкц...           72
# 1    « онлайн-ритейл менеджмент . сопровождение выв...           72
# 2    " цифровой маркетинг . digital маркетолог-проф...           72
# 3                              системный администратор           72
# 4                машинный обучение . начальный уровень           72
# ..                                                 ...          ...
# 423             проектирование реляционный база данные           72
# 424               цифровой технология в индустрия мода           72
# 425                   « создание инновация в ar и vr »           72
# 426                      программирование на с / с + +           72
# 427                                    цифровой дизайн           72
#
#      hours_prac  online  difficulty  min_listeners  max_listeners  taxonomy  \
# 0            72    True  продвинуть             10             10  0.079692
# 1            41    True   начальный            100            100  0.062753
# 2             0    True     базовый             20           3000  0.047428
# 3             0    True     базовый              8           1000  0.107969
# 4            66    True   начальный            100            999  0.143621
# ..          ...     ...         ...            ...            ...       ...
# 423          45    True     базовый              5             40  0.097057
# 424          60    True     базовый              1            100  0.042857
# 425          58    True   начальный             42            700  0.077844
# 426          48    True     базовый              5             40  0.014696
# 427           0    True     базовый              0              0  0.000000
#
#      expected_taxonomy_match  positive_reviews  neutral_reviews  \
# 0                   0.571429                15               60
# 1                   1.000000                 0                0
# 2                   1.000000                 0                0
# 3                   0.285714               114              335
# 4                   1.000000                 0                0
# ..                       ...               ...              ...
# 423                 1.000000                 3               19
# 424                 0.666667                 5               19
# 425                 1.000000                 0                0
# 426                 1.000000                 0                0
# 427                 0.000000                 0                0
#
#      negative_reviews
# 0                   4
# 1                   0
# 2                   0
# 3                  36
# 4                   0
# ..                ...
# 423                 2
# 424                 0
# 425                 0
# 426                 0
# 427                 0
#
# [428 rows x 12 columns]

# %%
import passport, passport_predictor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-72723d14e885> in <module>
# ----> 1 import passport, passport_predictor
#
# ModuleNotFoundError: No module named 'passport'

# %%
sys.path
# Out:
# '/home/alex/Desktop/epc-backend/epc'
